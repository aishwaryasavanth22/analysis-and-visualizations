# %% [markdown]
# #### NOTES ON HOW TO HANDLE MISSING AND NULL VALUES

# %% [markdown]
# #### About this file:
# I worked upon the melbourne dataset to show how to deal with missing data/messy data and clean it.
#
# **Dataset(Download-Link):** https://drive.google.com/file/d/1A-ZOIOpbHbpGti2_9XTLI8QZxrGv8Eyx/view?usp=drive_link
#
# **This file shows:**
# - Types of data we need to clean
# - How to **treat missing data and it's types**
# - **Method's to filter out missing data**
# - How to **identify missing values** in the data
# - Method's to **impute or fill missing values**
# - **Indexing to filter rows**
# - Different **types of missing data**
# - how to **get percentage of missing values for each column**
# - **sorting of values of one column in ascending/descending column**
# - **KNN Imputation** instead of imputing with mean/median
# - few key takeaways from handling the missing to keep in mind
# - Dealing with duplicate data
# - **Create new columns by splitting the data from existing columns**

# %% [markdown]
# **Data Wrangling:** The process of making data ready for analysis is called Data Wrangling.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Generally the data that we collect is not ready for analysis. It has various issues like:
#
# - Missing Values
# - Null Values
# - Incorrect Format
# - Duplicate Values
# - Incorrect Data
# - Unnecessary Data
# - Improper Column Names etc

# %% [markdown]
# ### Missing Data

# %% [markdown]
# Data could be missing because of various reasons like the observation does not exist, was not observed or was not recorded properly.
#
# Missing data is often represented in following ways:
#
# - NA, N/A
# - Blank cell
# - Dashes (-, --)
# - Values like -1, 999
#
# We can do following to handle missing data:
#
# - Deleting observations(rows) with missing or invalid values.
# - Substituting or filling them with suitable values.
# - Deleting or keeping outlier based on whether they are good or bad.
# - Deleting the duplicates if they are not valid.
#
# ### Some methods we use to filter out the missing data:
#
# - isnull() - to identify the missing values
# - notnull() - opposite of isnull()
# - dropna() - to drop the observations consisting of missing values. Here we can
# mention some parameters to properly drop the observations.
#
#
# ### Some methods to impute/fill the missing values:
#
# - Fill with a constant value.
# - Fill with the mean or median of the data in case of numerical data.
# - Advance imputation with KNN Imputation.
# - And in the case of Time-Series data we can use:
# - Forward Fill (ffill)
# - Backward Fill (bfill)
#
# ### Indexing the columns to filter rows
#
# - df[0] filters the first column.
#
# - df[0].notnull() applies the notnull() operation over the df[0] series and returns a series of True/False values.
#
# - df[df[0].notnull()] returns those rows of the DataFrame where the first column has non-null values.
#
#
# ### Indexing the rows to filter columns
#
# - df.loc[0] filters the first row.
#
# - df.loc[0].notnull() applies the notnull() operation over the df.loc[0] DataFrame and returns a DataFrame of True/False values corresponding to the first row.
#
# - df.loc[:,df.loc[0].notnull()] returns those columns of the DataFrame where the first row has non-null values.
#
#
# ### Different types of missing data
#
# - But there’s more to missing data than missingness. Missing data comes in four varieties:
#
# - Structurally Missing Data: we expect this data to be missing for some logical reason
#
# - Missing Completely at Random (MCAR): the probability of any datapoint being MCAR is the same for all data points – this type of missing data is mostly hypothetical. MCAR data is truly only MCAR if every potential observation is equally likely to be missing a value for that variable. There’s no logic, no outside force, or unseen behavior. It’s just a completely random, fluke occurrence that there isn’t data.
#
# - Missing at Random (MAR): Missing at Random might be the most complex of the missing data types. If the likelihood of missingness is different for different groups, but equally likely within a group, then that data is missing at random. It’s kind of a hybrid of missing for a reason and missing completely at random. Ex : several scientific studies have shown that individuals do not like to report their weight, especially when they have a Body Mass Index (BMI) outside of the “normal” range. This is an example of Missing at Random data because we can assume that some groups are not reporting their weight for a reason, but that anyone within that group (i.e., someone with a non-“normal” BMI) has an equal probability of not reporting their weight.
#
# - Missing Not at Random (MNAR) : There is some reason why the data is missing

# %% [markdown]
# ## Lets deal with missing data and clean it.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("melbourne.csv")

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.8014    144.9958  Northern Metropolitan
# 1        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 3        NaN        Yarra  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.8014    144.9958  Northern Metropolitan
# 1        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 3        NaN        Yarra  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Identifying Missing Values
#
# The methods isnull() and notnull() are the most common ways of identifying missing values.
#
# While handling missing data, you first need to identify the rows and columns containing missing values, count the number of missing values, and then decide how you want to treat them.
#
# It is important that you treat missing values in each column separately, rather than implementing a single solution (e.g. replacing NaNs by the mean of a column) for all columns.
#
# isnull() returns a boolean (True/False) which can then be used to find the rows or columns containing missing values.

# %%
df.shape
# Out:
# (23547, 21)

# %%
# check the number of missing values in each columns
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
# count of column which has atleat 1 missing value.
df.isnull().any().sum()
# Out:
# 14

# %%
# list of all the columns which has any missing values
df.columns[df.isnull().any()]
# Out:
# Index(['Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# list of all rows which has atleast one missing values
df.isnull().any(axis = 1)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 23542     True
# 23543     True
# 23544     True
# 23545     True
# 23546     True
# Length: 23547, dtype: bool

# %%
# select rows in which all the values are missing
df[df.isnull().all(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# As of now, we have identified the missing values in rows and columns. Now we need to treat them appropriately.
#
# ### There are mainly two things we can do to treat the missing values:
#
# 1. Delete the missing value
#    - Delete the rows consisting of missing values
#    - Delete the columns consisting of missing values
# 2. Impute/ Fill the missing values
#    - With a constant, mean, median, mode etc
#    - Using predictive models like KNN, SVM etc.

# %% [markdown]
# Now keep in mind that if delete the missing values then we loose a lot of data and we might not be left with enough data to work with. And when we fill, we fill with assumed values which might bring a lot of made up values in our data. That way we loose authenticity of the data

# %% [markdown]
# ### Let's treat missing values in a column

# %%
round(100 * (df.isnull().sum() / len(df)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %% [markdown]
# Above we can see a lot of missing values in few columns. So to decide whether to delete the missing values or fill it, we need to look at the:
#
# - The importance of a given column
# - The size the data available to us.
# - And the task for which the data is being used.
#
# For example, if you look at the price column, that is the most important column if we are going to use this data for predictive modelling, so we can't delete that column.
#
# On the other hand we have columns like BuildingArea and YearBuilt which has more than 50% data. Here we can't delete the rows or fill the values since either we will loose more than half the data or we bring in a heavy bias in the data by filling it.

# %%
# dropping the columns which missing values more than 30%
df.drop(columns = ["BuildingArea", "YearBuilt", "CouncilArea"], inplace = True)

# %% [markdown]
# ### Let's treat the missing values in rows

# %%
round((df.isnull().sum() / len(df)) * 100, 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df.shape
# Out:
# (23547, 18)

# %% [markdown]
# Now we are left with 18 columns which means 18 values in every row. So if any row has suppose more than 5 missing values then we would drop those.

# %%
df[df.isnull().sum(axis = 1) > 5]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...                  ...                  ...    ...  ...        ...    ...
# 23495  Templestowe Lower  1/207 Manningham Rd      2    u   550000.0     PI
# 23499          Thornbury      1/128 Dundas St      2    t   770000.0     PI
# 23502          Thornbury        111 Pender St      2    t   858000.0      S
# 23508             Toorak   21/1059 Malvern Rd      2    u   720000.0     VB
# 23531           Werribee         91 Latham St      4    h   540000.0     PI
#
#             SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 15           Jellis  08-10-2016       2.5    3067.0       NaN       NaN  NaN
# 16           Jellis  08-10-2016       2.5    3067.0       NaN       NaN  NaN
# 19           Dingle  08-10-2016       2.5    3067.0       NaN       NaN  NaN
# 21           Biggin  10-12-2016       2.5    3067.0       NaN       NaN  NaN
# 22     Purplebricks  10-12-2016       2.5    3067.0       NaN       NaN  NaN
# ...             ...         ...       ...       ...       ...       ...  ...
# 23495         Barry  26-08-2017      12.4    3107.0       NaN       NaN  NaN
# 23499       McGrath  26-08-2017       7.0    3071.0       NaN       NaN  NaN
# 23502        Jellis  26-08-2017       7.0    3071.0       NaN       NaN  NaN
# 23508        Beller  26-08-2017       4.1    3142.0       NaN       NaN  NaN
# 23531       Triwest  26-08-2017      14.7    3030.0       NaN       NaN  NaN
#
#        Landsize  Lattitude  Longtitude             Regionname  Propertycount
# 15          NaN        NaN         NaN  Northern Metropolitan         4019.0
# 16          NaN        NaN         NaN  Northern Metropolitan         4019.0
# 19          NaN        NaN         NaN  Northern Metropolitan         4019.0
# 21          NaN        NaN         NaN  Northern Metropolitan         4019.0
# 22          NaN        NaN         NaN  Northern Metropolitan         4019.0
# ...         ...        ...         ...                    ...            ...
# 23495       NaN        NaN         NaN   Eastern Metropolitan         5420.0
# 23499       NaN        NaN         NaN  Northern Metropolitan         8870.0
# 23502       NaN        NaN         NaN  Northern Metropolitan         8870.0
# 23508       NaN        NaN         NaN  Southern Metropolitan         7217.0
# 23531       NaN        NaN         NaN   Western Metropolitan        16166.0
#
# [4278 rows x 18 columns]

# %%
sorted_df = df.sort_values('Lattitude', ascending = False)

# %%
msno.matrix(sorted_df)

# %% [markdown]
# If we notice the above output, we can see a clear pattern that in many of the rows the same column values are missing which indicates that the data collection was not properly done for these houses. Hence we might drop these because they are probably not very useful for us.

# %%
len(df[df.isnull().sum(axis = 1) > 5])
# Out:
# 4278

# %%
(len(df[df.isnull().sum(axis = 1) > 5])/ len(df))*100
# Out:
# 18.16791948018856

# %% [markdown]
# We have 18% rows which consists of missing values. Here we are going to drop these.

# %%
df = df[~(df.isnull().sum(axis = 1) > 5)]

# %%
round((df.isnull().sum() / len(df)) * 100, 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %% [markdown]
# - Most of the missing values are treated but we still have a large amount of missing values in Price column. So are going to fill these or delete?
#
# - As we saw before, the price column is the most important column if we are going to use this data for predictive modelling. So if we decide to fill these then our data will have huge bias and it will become more synthetic rather than original and genuine.
#
# - Hence we decide to delete the rows where the price is missing

# %%
df = df[~np.isnan(df["Price"])]

# %%
df.shape
# Out:
# (15086, 18)

# %% [markdown]
# Now going to the Landsize column, we will see whether we can impute the missing values or not.
#
# The decision to impute the missing value depends on the spread/distribution of the data in that column. If the spread of the data is very then we can impute otherwise it will be risky.

# %%
df["Landsize"].describe()
# Out:
# count     13603.000000
# mean        558.116371
# std        3987.326586
# min           0.000000
# 25%         176.500000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %% [markdown]
# Here since the variation in the data is too high so we can't impute. We will rather go for deleting the missing values.

# %%
df = df[~np.isnan(df['Landsize'])]

# %% [markdown]
# Next, let's look at Lattitude and Longtitude columns. There is a high chance that the same rows will have both the values missing since both are written together and one of these don't make sense alone.

# %%
#rows with Lattitude values missing
df[np.isnan(df['Lattitude'])] #output confirms that both values are missing together in same rows
# Out:
#                    Suburb                Address  Rooms Type      Price  \
# 2572              Burwood           23 Monica St      3    h   990000.0
# 3257         Clifton Hill  3/268 Alexandra Pde E      1    u   363000.0
# 4485            Footscray          483 Barkly St      3    t   781000.0
# 5170         Hampton East           7 Seafoam St      4    t  1185000.0
# 10745  Williamstown North         4/9 Adeline St      1    u   355000.0
# 13223           Melbourne   1913/228 Abeckett St      3    u  1175000.0
# 14008            Brooklyn          9 Richards Ct      3    h   750000.0
# 14132     North Melbourne   13/201 Abbotsford St      2    t   755000.0
# 14139      Oakleigh South            4 Druitt St      4    h  1205500.0
# 14142      Oakleigh South        298 Warrigal Rd      3    h   799999.0
# 14143      Oakleigh South            11 Yarra Ct      5    h  1200000.0
# 14976            Essendon        9 Washington St      3    h  1520000.0
# 15278              Seddon          60 Station Rd      4    h  1500000.0
# 15561             Croydon       3 Silvergrass Ct      3    h   630000.0
# 16358          Kensington     201/102 Rankins Rd      2    u   876000.0
# 16564          Strathmore          48 Lebanon St      3    h   950000.0
# 17616          Kensington     109/102 Rankins Rd      1    u   410000.0
# 17620         Keysborough          19 Denmark Rd      5    h  1100000.0
# 18141               Lalor           83 Rotino Cr      3    t   463000.0
# 18614           Mickleham        17 Primavera Dr      4    h   610000.0
# 18793             Wollert      13 Strathalbyn Ch      4    h   631000.0
# 18995           Greenvale         40 Frontier Av      3    t   470000.0
#
#       Method        SellerG        Date  Distance  Postcode  Bedroom2  \
# 2572      VB      Fletchers  17-09-2016      11.7    3125.0       3.0
# 3257       S  hockingstuart  27-06-2016       3.4    3068.0       1.0
# 4485       S            Jas  27-11-2016       6.4    3011.0       3.0
# 5170       S             RT  28-05-2016      14.5    3188.0       4.0
# 10745      S        Sweeney  27-11-2016       8.9    3016.0       1.0
# 13223     PI           Icon  29-04-2017       2.8    3000.0       3.0
# 14008      S  hockingstuart  20-05-2017      10.9    3012.0       3.0
# 14132     PI         Nelson  29-04-2017       2.3    3051.0       2.0
# 14139      S       Woodards  22-04-2017      14.7    3167.0       4.0
# 14142      S       Woodards  29-04-2017      14.7    3167.0       3.0
# 14143     PI         Buxton  29-04-2017      14.7    3167.0       5.0
# 14976      S           Brad  03-06-2017       7.5    3040.0       3.0
# 15278     SP        Sweeney  03-06-2017       5.1    3011.0       4.0
# 15561      S        McGrath  17-06-2017      23.0    3136.0       3.0
# 16358      S        Rendina  24-06-2017       3.4    3031.0       2.0
# 16564     PI      Considine  24-06-2017       8.2    3041.0       3.0
# 17616     PI        Rendina  08-07-2017       3.4    3031.0       1.0
# 17620     PI       VicHomes  08-07-2017      25.2    3173.0       5.0
# 18141      S            HAR  12-08-2017      16.3    3075.0       3.0
# 18614      S            Ray  15-07-2017      20.6    3064.0       4.0
# 18793     PI  hockingstuart  15-07-2017      25.5    3750.0       4.0
# 18995     SP          Barry  22-07-2017      20.4    3059.0       3.0
#
#        Bathroom  Car  Landsize  Lattitude  Longtitude  \
# 2572        2.0  2.0     263.0        NaN         NaN
# 3257        1.0  1.0       0.0        NaN         NaN
# 4485        2.0  2.0      98.0        NaN         NaN
# 5170        3.0  1.0     300.0        NaN         NaN
# 10745       1.0  1.0      46.0        NaN         NaN
# 13223       3.0  2.0       0.0        NaN         NaN
# 14008       1.0  2.0     667.0        NaN         NaN
# 14132       1.0  1.0    1537.0        NaN         NaN
# 14139       2.0  2.0     553.0        NaN         NaN
# 14142       2.0  4.0     590.0        NaN         NaN
# 14143       2.0  2.0     532.0        NaN         NaN
# 14976       2.0  1.0     321.0        NaN         NaN
# 15278       3.0  2.0     169.0        NaN         NaN
# 15561       2.0  2.0     319.0        NaN         NaN
# 16358       2.0  2.0       0.0        NaN         NaN
# 16564       2.0  2.0     216.0        NaN         NaN
# 17616       1.0  1.0    1053.0        NaN         NaN
# 17620       3.0  2.0     522.0        NaN         NaN
# 18141       2.0  2.0     114.0        NaN         NaN
# 18614       2.0  2.0     490.0        NaN         NaN
# 18793       2.0  2.0     400.0        NaN         NaN
# 18995       2.0  2.0     201.0        NaN         NaN
#
#                        Regionname  Propertycount
# 2572        Southern Metropolitan         5678.0
# 3257        Northern Metropolitan         2954.0
# 4485         Western Metropolitan         7570.0
# 5170        Southern Metropolitan         2356.0
# 10745        Western Metropolitan          802.0
# 13223       Northern Metropolitan        17496.0
# 14008        Western Metropolitan          962.0
# 14132       Northern Metropolitan         6821.0
# 14139  South-Eastern Metropolitan         3692.0
# 14142  South-Eastern Metropolitan         3692.0
# 14143  South-Eastern Metropolitan         3692.0
# 14976        Western Metropolitan         9264.0
# 15278        Western Metropolitan         2417.0
# 15561        Eastern Metropolitan        11925.0
# 16358       Northern Metropolitan         5263.0
# 16564        Western Metropolitan         3284.0
# 17616       Northern Metropolitan         5263.0
# 17620  South-Eastern Metropolitan         8459.0
# 18141       Northern Metropolitan         8279.0
# 18614       Northern Metropolitan         1158.0
# 18793       Northern Metropolitan         2940.0
# 18995       Northern Metropolitan         4864.0

# %%
df[["Lattitude", "Longtitude"]].describe()
# Out:
#           Lattitude    Longtitude
# count  13581.000000  13581.000000
# mean     -37.809204    144.995221
# std        0.079257      0.103913
# min      -38.182550    144.431810
# 25%      -37.856820    144.929600
# 50%      -37.802360    145.000100
# 75%      -37.756400    145.058320
# max      -37.408530    145.526350

# %%
# filling the missing values of Lattitude and Longtitude with mean fo the columns.
df["Lattitude"] = df["Lattitude"].fillna(df["Lattitude"].mean())
df["Longtitude"] = df["Longtitude"].fillna(df["Longtitude"].mean())

# %%
round((df.isnull().sum() / len(df)) * 100, 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %% [markdown]
# Let's fix the last two remaining columns Car and Bathroom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13603 entries, 1 to 23545
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13603 non-null  object
#  1   Address        13603 non-null  object
#  2   Rooms          13603 non-null  int64
#  3   Type           13603 non-null  object
#  4   Price          13603 non-null  float64
#  5   Method         13603 non-null  object
#  6   SellerG        13603 non-null  object
#  7   Date           13603 non-null  object
#  8   Distance       13603 non-null  float64
#  9   Postcode       13603 non-null  float64
#  10  Bedroom2       13603 non-null  float64
#  11  Bathroom       13602 non-null  float64
#  12  Car            13540 non-null  float64
#  13  Landsize       13603 non-null  float64
#  14  Lattitude      13603 non-null  float64
#  15  Longtitude     13603 non-null  float64
#  16  Regionname     13603 non-null  object
#  17  Propertycount  13603 non-null  float64
# dtypes: float64(10), int64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# Here car and bathroom columns are in float which is incorrect as there can't be 1.3 bathrooms or 2.4 cars. So we need to change the datatype of this column to object type.

# %%
df["Car"] = df["Car"].astype('object')
df["Bathroom"] = df["Bathroom"].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13603 entries, 1 to 23545
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13603 non-null  object
#  1   Address        13603 non-null  object
#  2   Rooms          13603 non-null  int64
#  3   Type           13603 non-null  object
#  4   Price          13603 non-null  float64
#  5   Method         13603 non-null  object
#  6   SellerG        13603 non-null  object
#  7   Date           13603 non-null  object
#  8   Distance       13603 non-null  float64
#  9   Postcode       13603 non-null  float64
#  10  Bedroom2       13603 non-null  float64
#  11  Bathroom       13602 non-null  object
#  12  Car            13540 non-null  object
#  13  Landsize       13603 non-null  float64
#  14  Lattitude      13603 non-null  float64
#  15  Longtitude     13603 non-null  float64
#  16  Regionname     13603 non-null  object
#  17  Propertycount  13603 non-null  float64
# dtypes: float64(8), int64(1), object(9)
# memory usage: 2.0+ MB

# %%
df['Car'].value_counts()
# Out:
# Car
# 2.0     5606
# 1.0     5515
# 0.0     1026
# 3.0      748
# 4.0      507
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df['Car'] = df['Car'].fillna(2)

# %%
df['Bathroom'].value_counts()
# Out:
# Bathroom
# 1.0    7517
# 2.0    4987
# 3.0     921
# 4.0     106
# 0.0      34
# 5.0      28
# 6.0       5
# 7.0       2
# 8.0       2
# Name: count, dtype: int64

# %%
df['Bathroom'] = df['Bathroom'].fillna(1.0)

# %%
df['Bathroom']
# Out:
# 1        1.0
# 2        1.0
# 4        2.0
# 5        2.0
# 6        1.0
#         ...
# 23537    2.0
# 23538    2.0
# 23539    2.0
# 23541    1.0
# 23545    1.0
# Name: Bathroom, Length: 13603, dtype: float64

# %% [markdown]
# ## We can also do KNN Imputation instead of imputing with mean or median.

# %%
from sklearn.impute import KNNImputer
knn_imputer = KNNImputer()

# %%
# dealing with missing values using knn imputation
df_2["Price"] = knn_imputer.fit_transform(df_2[['Price']])
df_2['Price'] = round(df_2['Price'], 2)

# %% [markdown]
# ## Few key takeaways from handling the missing to keep in mind
#
# - We can't just delete the missing values because that will result in loss of huge amount of data and then the data might not represent what happens really in the data and we would not confidence in the accuracy of the insights and observations.
#
# - But we can safely delete the data when it is MAR or MCAR since the data loss is completely random and not because of any reason. However in this case if the missing data is too large then we can't delete all of it.
# If the data has low correlation with other features and is not very important for the task at hand then we can delete them safely.
#
# - When deleting the rows completely, the amount of these rows should be generally less than 5%.
#
# - If a column has too many missing values we try to retain it first by fixing the missing values as much as possible but we can drop the column if more than 60% values are missing.

# %% [markdown]
# ## Dealing with Duplicate data

# %%
data_2 = pd.read_csv('melbourne.csv')

# %%
data_2.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.8014    144.9958  Northern Metropolitan
# 1        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 3        NaN        Yarra  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
#Identify the duplicate rows
data_2.duplicated().sum()
# Out:
# 1

# %%
#check the rows which are duplicate
data_2[data_2.duplicated()]
# Out:
#            Suburb        Address  Rooms Type  Price Method SellerG  \
# 15858  Nunawading  1/7 Lilian St      3    t    NaN     SP  Jellis
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 15858  17-06-2017      15.4    3131.0  ...       3.0  2.0     405.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 15858         226.0     2000.0   Whitehorse -37.82678   145.16777
#
#                  Regionname Propertycount
# 15858  Eastern Metropolitan        4973.0
#
# [1 rows x 21 columns]

# %%
#drop all the duplicate rows from the data
data_2.drop_duplicates(inplace = True)

# %%
data_2.duplicated(subset = 'Price')
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 23542     True
# 23543     True
# 23544     True
# 23545     True
# 23546     True
# Length: 23546, dtype: bool

# %%
#only consider certain columns for identifying duplicates using subsets parameter
data_2[data_2.duplicated(subset = 'Price')]
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 3        Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 7        Abbotsford         16 Maugie St      4    h        NaN     SN
# 8        Abbotsford         53 Turner St      2    h        NaN      S
# 9        Abbotsford         99 Turner St      2    h        NaN      S
# 12       Abbotsford  121/56 Nicholson St      2    u        NaN     PI
# ...             ...                  ...    ...  ...        ...    ...
# 23542  Wyndham Vale      25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale     19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie         17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville           6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville        33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 3             Rounds  04-02-2016       2.5    3067.0  ...       2.0  1.0
# 7             Nelson  06-08-2016       2.5    3067.0  ...       2.0  2.0
# 8             Biggin  06-08-2016       2.5    3067.0  ...       1.0  2.0
# 9            Collins  06-08-2016       2.5    3067.0  ...       2.0  1.0
# 12            Biggin  07-11-2016       2.5    3067.0  ...       2.0  1.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 23542      Harcourts  26-08-2017      27.2    3024.0  ...       1.0  0.0
# 23543  hockingstuart  26-08-2017      27.2    3024.0  ...       NaN  NaN
# 23544     Buckingham  26-08-2017      12.7    3085.0  ...       3.0  2.0
# 23545        Village  26-08-2017       6.3    3013.0  ...       1.0  1.0
# 23546        Village  26-08-2017       6.3    3013.0  ...       2.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 3           0.0           NaN        NaN        Yarra -37.81140   145.01160
# 7         400.0         220.0     2006.0        Yarra -37.79650   144.99650
# 8         201.0           NaN     1900.0        Yarra -37.79950   144.99740
# 9         202.0           NaN     1900.0        Yarra -37.79960   144.99890
# 12       4292.0          82.0     2009.0        Yarra -37.80780   144.99650
# ...         ...           ...        ...          ...       ...         ...
# 23542     552.0         119.0     1990.0          NaN -37.90032   144.61839
# 23543       NaN           NaN        NaN          NaN -37.87882   144.60184
# 23544       NaN           NaN        NaN          NaN -37.72006   145.10547
# 23545     362.0         112.0     1920.0          NaN -37.81188   144.88449
# 23546       NaN         139.0     1950.0          NaN -37.81829   144.87404
#
#                   Regionname Propertycount
# 3      Northern Metropolitan        4019.0
# 7      Northern Metropolitan        4019.0
# 8      Northern Metropolitan        4019.0
# 9      Northern Metropolitan        4019.0
# 12     Northern Metropolitan        4019.0
# ...                      ...           ...
# 23542   Western Metropolitan        5262.0
# 23543   Western Metropolitan        5262.0
# 23544  Northern Metropolitan        1369.0
# 23545   Western Metropolitan        6543.0
# 23546   Western Metropolitan        6543.0
#
# [21075 rows x 21 columns]

# %%
#To drop all the rows where the price is same 
data_2.drop_duplicates(subset = 'Price')
# Out:
#                   Suburb           Address  Rooms Type      Price Method  \
# 0             Abbotsford     68 Studley St      2    h        NaN     SS
# 1             Abbotsford      85 Turner St      2    h  1480000.0      S
# 2             Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford      5 Charles St      3    h  1465000.0     SP
# 5             Abbotsford  40 Federation La      3    h   850000.0     PI
# ...                  ...               ...    ...  ...        ...    ...
# 23328     Mount Waverley     15 Anthony Dr      3    h  1028800.0      S
# 23461         Strathmore    4 Collegian Av      3    h  1848000.0      S
# 23468           Sunshine      9 Appleby Ct      3    h   717500.0      S
# 23493  Templestowe Lower         7 Dove Ct      4    h  1288000.0      S
# 23514            Vermont    73 Nurlendi Rd      4    h  1263500.0      S
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Jellis  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0
# 1        Biggin  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0
# 2        Biggin  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0
# 4        Biggin  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0
# 5        Biggin  04-03-2017       2.5    3067.0  ...       2.0  1.0      94.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 23328    Jellis  26-08-2017      14.2    3149.0  ...       2.0  1.0     470.0
# 23461  McDonald  26-08-2017       8.2    3041.0  ...       1.0  3.0     824.0
# 23468     Barry  26-08-2017      10.5    3020.0  ...       1.0  1.0     554.0
# 23493     Barry  26-08-2017      12.4    3107.0  ...       2.0  2.0     948.0
# 23514     Barry  26-08-2017      17.2    3133.0  ...       2.0  2.0     791.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.80140   144.99580
# 1               NaN        NaN        Yarra -37.79960   144.99840
# 2              79.0     1900.0        Yarra -37.80790   144.99340
# 4             150.0     1900.0        Yarra -37.80930   144.99440
# 5               NaN        NaN        Yarra -37.79690   144.99690
# ...             ...        ...          ...       ...         ...
# 23328         118.0     1960.0          NaN -37.88751   145.13545
# 23461         189.0     1935.0          NaN -37.73797   144.92455
# 23468          95.0     1985.0          NaN -37.78514   144.84561
# 23493           NaN        NaN          NaN -37.76078   145.10696
# 23514           NaN        NaN          NaN -37.84467   145.19276
#
#                   Regionname Propertycount
# 0      Northern Metropolitan        4019.0
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# 5      Northern Metropolitan        4019.0
# ...                      ...           ...
# 23328   Eastern Metropolitan       13366.0
# 23461   Western Metropolitan        3284.0
# 23468   Western Metropolitan        3755.0
# 23493   Eastern Metropolitan        5420.0
# 23514   Eastern Metropolitan        4181.0
#
# [2471 rows x 21 columns]

# %% [markdown]
# ## Create new columns by splitting the data from existing columns

# %%
data_2.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.8014    144.9958  Northern Metropolitan
# 1        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 3        NaN        Yarra  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Suppose we want to split the date column and create 3 new columns : day, month and year.

# %%
data_2['Date'].str.split('-')
# Out:
# 0        [03, 09, 2016]
# 1        [03, 12, 2016]
# 2        [04, 02, 2016]
# 3        [04, 02, 2016]
# 4        [04, 03, 2017]
#               ...
# 23542    [26, 08, 2017]
# 23543    [26, 08, 2017]
# 23544    [26, 08, 2017]
# 23545    [26, 08, 2017]
# 23546    [26, 08, 2017]
# Name: Date, Length: 23546, dtype: object

# %%
data_2['day'] = data_2['Date'].str.split('-').str.get(0)
data_2['month'] = data_2['Date'].str.split('-').str.get(1)
data_2['year'] = data_2['Date'].str.split('-').str.get(2)

# %%
data_2.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  BuildingArea  YearBuilt  CouncilArea  \
# 0  03-09-2016       2.5    3067.0  ...           NaN        NaN        Yarra
# 1  03-12-2016       2.5    3067.0  ...           NaN        NaN        Yarra
# 2  04-02-2016       2.5    3067.0  ...          79.0     1900.0        Yarra
# 3  04-02-2016       2.5    3067.0  ...           NaN        NaN        Yarra
# 4  04-03-2017       2.5    3067.0  ...         150.0     1900.0        Yarra
#
#    Lattitude  Longtitude             Regionname Propertycount  day  month  \
# 0   -37.8014    144.9958  Northern Metropolitan        4019.0   03     09
# 1   -37.7996    144.9984  Northern Metropolitan        4019.0   03     12
# 2   -37.8079    144.9934  Northern Metropolitan        4019.0   04     02
# 3   -37.8114    145.0116  Northern Metropolitan        4019.0   04     02
# 4   -37.8093    144.9944  Northern Metropolitan        4019.0   04     03
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2017
#
# [5 rows x 24 columns]
