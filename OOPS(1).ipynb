# %% [markdown]
# #### OOPS Hand's On

# %%
# 1. Create a function named 'factor' that can only accept 1 argument. The function should return the factorial of that number.

def factorial(n):
    fact = 1
    # check if number is +ve or -ve"
    if n < 0:
        print('Invalid')
    elif n == 0:
        print('Factorial of zero is 1')
    else:
        for i in range(1, n + 1):
            fact = fact * i
        print('Factorial:', fact)

n = int(input('Enter the number: '))
factorial(n)
# Out:
# Factorial: 720

# %%
# 2nd way 
import math
def fact(n):
    return math.factorial(n)

n = int(input('Enter the number: '))
print(fact(n))
# Out:
# 720

# %%
# 2. Create a function named ‘check_string’, the function should accept a string data from the user and the function should check if the user input contains the letter ‘s’ in it. If it contains the letter ‘s’ then print- ‘The string is containing the letter ‘s’, if not then print- ‘The string doesn’t contain the letter ‘s’

def check_string(s):
    if 's' in s.lower():
        print('The string is containing the letter s')
    else:
        print('The string doesn’t contain the letter s')
        
s = input('Enter the string: ')
check_string(s)
# Out:
# The string is containing the letter s

# %%
# 3. Create a class named ‘student’ and inside the class, create a function named ‘fun1’- this method should accept the user defined input and return that value.

# a. Create another method named- message() and that method should print the user defined input that we have defined in ‘fun1’

class student:
    def fun1(self):
        num = int(input("Enter the number: "))
        print(num)
    
    def message(self):
        return self.fun1()

obj = student()
obj.message()

# Enter the number = 5
# Out:
# 5

# %%
# 4. Create a lambda function that should double or multiply the number (that we will be passing in the lambda function) by 2. Store the lambda function in a variable named ‘double_num’.

double_num = lambda x: x*2
double_num(8)
# Out:
# 16

# %%
# 5. Create a class named ‘Super’ and inside that class define a user-defined function named fun1.

# a. Inside the ‘fun1’ function, pass the message “This is function 1 in the Super class.” in the print statement.

class Super:
    def fun1(self):
        print("This is function 1 in the Super class")

o = Super()
o.fun1()
# Out:
# This is function 1 in the Super class

# %%
# 6. Create another class named ‘Modified_Super’ and inherit this class from the Super class.

# a. Inside the Modified_Super class, create a function named ‘fun1’ and pass the following message inside the print statement: ‘This is function 1 in the Modified Super class.’
# b. Create another user-defined function named ‘fun2’ and pass the message: ‘This is the 2nd function from the Modified Super class’ in the print statement.
# c. After that, now create an object for the Modified_Super class and call the fun1() and func2().

class Modified_Super(Super):
    def fun1(self): #Overriding
        print("This is function 1 in the Modified super class.")
    def fun2(self):
        print("This is the 2nd function from the Modified Super class.")

obj = Modified_Super()
obj.fun1()
# Out:
# This is function 1 in the Modified super class.

# %%
obj.fun2()
# Out:
# This is the 2nd function from the Modified Super class.

# %%
# 7. Create 2 methods named ‘Hello’. In the 1st Hello method, pass only one argument and pass this message: ‘This function only has 1 argument’. And in the 2nd Hello method, pass two arguments and pass this message: ‘This function has 2 arguments’.

# a. Try to call both the methods and analyze the output of both the methods

def Hello(arg1):
    print('Has 1 argument')
def Hello(arg1, arg2): # Method overloading
    print('Has 2 arguments')


# Hello 1
Hello(1,2)
# Out:
# Has 2 arguments

# %%
# 8. Create a method named ‘Sum’ that can accept multiple user inputs. Now add those userdefined input values using for loop and the function should return the addition of the n.
def Sum(*args): # Multiple user inputs
    s = 0
    for x in range(0, len(args)):
        s = s + args[x]
    return s

Sum(1, 1, 1, 22,5)
# Out:
# 30

# %%
Sum(8, 5, 4)
# Out:
# 17

# %%
Sum(5, 9, 10, 4, 5, 8, 9, 6, 4, 3, 5, 3, 2, 6, 7, 1, 2, 4, 6)
# Out:
# 99

# %%
# 9. Create a class named ‘Encapsulation’:

# a. Inside the class, first create a constructor. Inside the constructor, initialize originalValue variable as 10.

# b. After creating the constructor, define a function named ‘Value’ and this function should return the variable that we have initialized in the constructor.

# c. Now create 2nd function named setValue, and pass an argument named ‘newValue’. The task of this function will be to replace the value of the originalValue variable by the value of the newValue variable.

class Encapsulation:

    # a. Constructor to initialize originalValue as 10
    def __init__(self):
        self.originalValue = 10

    # b. Function to return the value of originalValue
    def Value(self):
        return self.originalValue

    # c. Function to update originalValue with newValue
    def setValue(self, newValue):
        self.originalValue = newValue


# Example usage:
obj = Encapsulation()
print(obj.Value())   # Output: 10

obj.setValue(50)
print(obj.Value())   # Output: 50
# Out:
# 10
# 50

# %%
# 10. Create a class named parent_Class and inside the class, initialize a global variable num as

# a. Create another class named child_Class and this class should be inherited from the parent class.

# b. Now create an object for the child_Class and with the help of child_Class object, display the value of ‘num’.

class parent_class:
    num = 10
    
class child_class(parent_class):
    pass

ob = child_class()
ob.num
# Out:
# 10

# %%
# 11. Create three classes named A, B, and C.

# a. Inside the A class, create a constructor. Inside the constructor, initialize 2 global variables- name and age.

# b. After initializing the global variables inside the constructor, now create a function named ‘details’ and that function should return the ‘name’ variable.

# c. Inside the B class, create a constructor. Inside the constructor, initialize 2 global variablesname and id.

# d. After initializing the global variables inside the constructor, now create a function named ‘details’ and that function should return the ‘name’ variable.

# e. The C class should inherit from class A, and B. Inside the class C, create a constructor, and inside the constructor, call the constructor of class A.

# f. Now, create a method inside the class C, as get_details, and this function should return the value of a name.

# g. Atlast, create an object of class C, and with the help of the object, call the get_details().

class A:
    def __init__(self):
        self.name = 'ABC'
        self.age = 28
        
    def details(self):
        return self.name
    
class B:
    def __init__(self):
        self.name = 'xyz'
        self.id = 1234
        
    def details(self):
        return self.name
    
class C(A, B): # Multiple Inheritance
    def __init__(self):
        A.__init__(self)
    
    def get_details(self):
        return self.name
    
obc = C()
obc.get_details()
# Out:
# 'ABC'

# %%
obc.age
# Out:
# 28

# %%
obc.name
# Out:
# 'ABC'

# %%
class A:
    def __init__(s, name, age):
        s.name = name
        s.age = age

    def details(s):
        return s.name

class B:
    def __init__(s, name, id):
        s.name = name
        s.id = id

    def details(s):
        return s.name

class C(A, B):
    def __init__(s, name, age, id):
        A.__init__(s, name, age)
        B.__init__(s, name, id)

    def get_details(s):
        return s.name

c = C('Test', 10, 101)
print(c.get_details())
print(f'Name - {c.name}, age - {c.age}, id - {c.id}')
# Out:
# Test
# Name - Test, age - 10, id - 101

# %%
# 12. Create a class named Employee, with a constructor ‘ init ’ method that accepts name and salary as parameters and set properties named name and salary.

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display(self):
        print('Name', self.name)
        print('Salary', self.salary)

e = Employee("Max", 200000)
e.display()
# Out:
# Name Max
# Salary 200000

# %%
# 2nd way
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        print(self.name, self.salary)
        
e1 = Employee("Sam", 40000)
# Out:
# Sam 40000

# %%
# 13. Define str method in Employee class so that when someone tries to print the object the string Name: employee_name, Salary: employee_salary is printed with the actual employee name and salary.
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def __str__(self):
        return f"Name: {self.name}, Salary: {self.salary}"
    
e = Employee("John", 50000)
print(e)
# Out:
# Name: John, Salary: 50000

# %%
e1 = Employee("Zuck", 4000000)
print(e1)
# Out:
# Name: Zuck, Salary: 4000000

# %%
e1.__str__()
# Out:
# 'Name: Zuck, Salary: 4000000'

# %%
# 14. Create a class named ‘Sub1’, inside the class, generate a user defined function named ‘first’ and inside the function, pass the following statement in the print()- ‘This is the first function from Sub 1 class’.

# a. Now create another class named ‘Sub2’, and inside the class, create a function named ‘second’, and pass the following message in the print()- ‘This is the second function from the Sub 2 class’.

# b. After that, create another class named ‘Super’ and inside that class, create a method named ‘final’, and pass the below message in the print()- ‘This is the final method from the super class’.

# c. Now, create an object for the Super class and call all the 3 user-defined methods, i.e., first(), second(), and final().

class Sub1:
    def first(self):
        print("This is the first function from Sub 1 class")
        
class Sub2(Sub1):
    def second(self):
        print("This is the second function from the Sub 2 class")
        
class Super(Sub2):
    def final(self):
        print("This is the final method from the super class")

# %%
s = Super()
s.first()
# Out:
# This is the first function from Sub 1 class

# %%
s.second()
# Out:
# This is the second function from the Sub 2 class

# %%
s.final()
# Out:
# This is the final method from the super class

# %%
# Another example:
class A:
    def set_name(self, name):
        self.name = name
        
class B:
    def set_salary(self, salary):
        self.salary = salary
        
class E(A, B):
    def __str__(self):
        return f"Name: {self.name}, Salary: {self.salary}"
    
e = E()
e.set_name("Jane")
e.set_salary(60000)
print(e)
# Out:
# Name: Jane, Salary: 60000

# %%
# 15. Create a class named ‘Parent’, and inside the class, create a function named ‘fun1’ and pass the following message in the print()- ‘This is the message from the fun1’.

# a. Now create a class named ‘Child1’ (inherits from Parent)and inside the class, create a method named ‘fun2’ and pass the following message in the print()- ‘This is the message from the fun2’.

# b. After that, create another class named ‘Child2’ (inherits from Parent) and inside the class, create a method named ‘fun3’ and pass the following message in the print()- ‘This is the message from the fun3’.

# c. Now, create an object of Child2 class and with the help of the object, call the ‘fun1’ method from the ‘Parent’ class.

class Parent:
    def fun1(self):
        print('This is the message from the fun1')
        
class Child1(Parent):
    def fun2(self):
        print("This is the message from the fun2")
        
class Child2(Parent):
    def fun3(self):
        print('This is the message from the fun3')
        
ob = Child2()
ob.fun1()
# Out:
# This is the message from the fun1

# %%
# 16. Create a class named ‘Parent’, and inside the class, create a function named ‘fun1’ and pass the following message in the print()- ‘This is the message from the fun1’.

# a. Now create a class named ‘Child’ and inside the class, create a method named ‘fun2’ and pass the following message in the print()- ‘This is the message from the fun2’.

# b. After that, create another class named ‘Hybrid’(Inherits from both Parent and Child) and inside the class, create a method named ‘fun3’ and pass the following message in the print()- ‘This is the message from the fun3’.

# c. Now, create an object of Hybrid class and with the help of the object, call the ‘fun1’, ‘fun2’, and ‘fun3’ methods

# Parent class
class Parent:
    def fun1(self):
        print("This is the message from the fun1")


# Child class
class Child:
    def fun2(self):
        print("This is the message from the fun2")


# Hybrid class inheriting from both Parent and Child
class Hybrid(Parent, Child):
    def fun3(self):
        print("This is the message from the fun3")


# Creating object of Hybrid class
obj = Hybrid()

# Calling all methods
obj.fun1()
obj.fun2()
obj.fun3()
# Out:
# This is the message from the fun1
# This is the message from the fun2
# This is the message from the fun3
